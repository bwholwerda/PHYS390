# %% [markdown]
# # Assignment 2 - Introduction to Python Programming Pt. 2
#
#
# ## Authors
# V. Aquiviva and B.W. Holwerda
#
# ## Learning Goals
# * Getting started on Python programming.
# * Syntax of python and Jupyter Notebooks.
#
# ## Keywords
# python, syntax, jupyter notebook,
#
# ## Companion Content
#
#
# ## Summary
#
# This is the first of two assignments to learn the first steps into python programming
#
# And now some credits. A lot of this material is gratefully adapted from
#
# http://github.com/jrjohansson/scientific-python-lectures.
#
# This work is licensed under a CC-BY license. and from
#
# https://github.com/jakevdp/WhirlwindTourOfPython.git
#
# The text is released under the CC-BY-NC-ND license, and code is released under the MIT license.
#
# <hr>

# %% [markdown]
# ## Student Name and ID:
#
#
#
# ## Date:
#
# <hr>

# %% [markdown]
# ### Lists

# %% [markdown]
# Lists are very similar to strings, except that
# #### each element can be of any type. ####
# The syntax for creating lists in Python is `[...]`:

# %%
l = [1,2,3,4]

print(type(l))
print(l)

# %% [markdown]
# We can use the same slicing techniques to manipulate lists as we could use on strings:

# %%
print(l)

print(l[1:3])

print(l[::2])

# %% [markdown]
# ** Indexing starts at 0 for lists as well **

# %%
l[0]

# %% [markdown]
# Elements in a list do not all have to be of the same type:

# %%
l = [1, 'a', 1.0, 1-1j]

print(l)

# %%
type(l)

# %% [markdown]
# Python lists can be inhomogeneous and arbitrarily nested:

# %%
nested_list = [1, [2, [3, [4, [5]]]]]

nested_list

# %%
len(nested_list)

# %% [markdown]
# Lists play a very important role in Python. For example they are used in loops and other flow control structures (discussed below). There are a number of convenient functions for generating lists of various types, for example the `range` function; however, later versions of Python require wrapping the object generated by the range function inside ``list()":

# %%
start = 10
stop = 30
step = 2

list(range(start, stop, step))

# %%
list(range(5))

# %%
import numpy as np

np.arange(start, stop, step)

# %% [markdown]
# The np.arange function works also when the step is not an integer:

# %%
np.arange(start, stop, 0.2)

# %% [markdown]
# #### Adding, inserting, modifying, and removing elements from lists

# %%
# create a new empty list
l = []

# add an elements using `append`
l.append("A")
l.append("d")
l.append("d")

print(l)

# %% [markdown]
# We can modify lists by assigning new values to elements in the list. In technical jargon, lists are *mutable*.

# %%
l[1] = "p"
l[2] = "p"

print(l)

# %%
l[1:3] = ["d", "d"]

print(l)

# %% [markdown]
# Insert an element at an specific index using `insert`

# %%
l.insert(0, "i")
l.insert(1, "n")
l.insert(2, "s")
l.insert(3, "e")
l.insert(4, "r")
l.insert(5, "t")

print(l)

# %% [markdown]
# Remove first element with specific value using 'remove'

# %%
l.remove("A")

print(l)

# %%
l.remove("d")

# %%
print(l)

# %% [markdown]
# Remove an element at a specific location using `del`:

# %%
#del l[7]
del l[5:6]

print(l)

# %% [markdown]
# There is a consequence of this "variable as pointer" approach that you need to be aware of. If we have two variable names pointing to the same mutable object, then changing one will change the other as well! For example, let's create and modify a list:

# %%
x = [1, 2, 3]

y = x

print(y)

# %% [markdown]
# We've created two variables x and y which both point to the same object. Because of this, if we modify the list via one of its names, we'll see that the "other" list will be modified as well:

# %%
x.append(4) # append 4 to the list pointed to by x

print(y) # y's list is modified as well!

# %% [markdown]
# This behavior might seem confusing if you're wrongly thinking of variables as buckets that contain data. But if you're correctly thinking of variables as pointers to objects, then this behavior makes sense.
#
# Note also that if we use "=" to assign another value to x, this will not affect the value of y – assignment is simply a change of what object the variable points to:

# %%
x = 'something else'

print(y)  # y is unchanged

# %% [markdown]
# Again, this makes perfect sense if you think of x and y as pointers, and the "=" operator as an operation that changes what the name points to.
#
# For example, it's perfectly safe to do operations like the following:

# %%
x = 10

y = x

x += 5  # add 5 to x's value, and assign it to x

print("x =", x)

print("y =", y)

# %% [markdown]
# See `help(list)` for more details, or read the online documentation.

# %% [markdown]
# ### Tuples

# %% [markdown]
# Tuples are like lists, except that they cannot be modified once created, that is they are *immutable*.
#
# In Python, tuples are created using the syntax `(..., ..., ...)`, or even `..., ...`:

# %%
point = (10, 20)

print(point, type(point))

# %%
point[0] = 20

# %% [markdown]
# Non-pro tip: Tuples show up a lot as the output of functions with multiple outputs.

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# Dictionaries are also like lists, except that each element is a key-value pair. The syntax for dictionaries is `{key1 : value1, ...}`:

# %%
params = {"parameter1" : 1.0,
          "parameter2" : 2.0,
          "parameter3" : 3.0,}

print(type(params))
print(params)

# %% [markdown]
# Until Python 3.6, dictionary entries did not have a specific order, but this has changed; see this post. https://stackoverflow.com/questions/4326658/how-to-index-into-a-dictionary

# %%
params.values(), params.keys()

# %% [markdown]
# ## A Quick Tour of Python Language Syntax ##
#
# Python was originally developed as a teaching language, but its ease of use and clean syntax have led it to be embraced by beginners and experts alike. The cleanliness of Python's syntax has led some to call it "executable pseudocode", and indeed my own experience has been that it is often much easier to read and understand a Python script than to read a similar script written in, say, C. Here we'll begin to discuss the main features of Python's syntax.
#
# Syntax refers to the structure of the language (i.e., what constitutes a correctly-formed program).

# %% [markdown]
# ## Comments Are Marked by ``#``
#
# Comments in Python are indicated by a pound sign (``#``), and anything on the line following the pound sign is ignored by the interpreter.
#
# A script can start with a comment:
# ``` python
# # now I'll tell you what I want to do
# ```
# But you can also have inline comments that follow a statement. For example:
# ``` python
# x += 2  # shorthand for x = x + 2
# ```

# %% [markdown]
# ### Consider the following code example, and let's comment each line together.

# %%
# 

midpoint = 5

# 

lower = []; upper = []

# 

for i in range(10): 

    if (i < midpoint):

        lower.append(i) #

    else:

        upper.append(i) #

        
print("lower:", lower)

print("upper:", upper)

# %% [markdown]
# ## End-of-Line Terminates a Statement
# The first line in the script is
# ``` python
# midpoint = 5
# ```
# This is an assignment operation, where we've created a variable named ``midpoint`` and assigned it the value ``5``.
# Notice that the end of this statement is simply marked by the end of the line.
# This is in contrast to languages like C and C++, where every statement must end with a semicolon (``;``).
#
# In Python, if you'd like a statement to continue to the next line, it is possible to use the "``\``" marker to indicate this:

# %%
x = 1 + 2 + 3 + 4 \
   + 5 + 6 + 7 + 8

# %%
x

# %% [markdown]
# It is also possible to continue expressions on the next line within parentheses, without using the "``\``" marker:

# %%
x = (1 + 2 + 3 + 4 +
     5 + 6 + 7 + 8)

# %% [markdown]
# Most Python style guides recommend the second version of line continuation (within parentheses) to the first (use of the "``\``" marker).

# %% [markdown]
# ## Indentation: Whitespace Matters!
# Next, we get to the main block of code:
# ``` Python
# for i in range(10):
#     if i < midpoint:
#         lower.append(i)
#     else:
#         upper.append(i)
# ```
# This is a compound control-flow statement including a loop and a conditional – we'll look at these types of statements in a moment.
# For now, consider that this demonstrates what is perhaps the most controversial feature of Python's syntax: whitespace is meaningful!
#
# In programming languages, a *block* of code is a set of statements that should be treated as a unit.
# In C, for example, code blocks are denoted by curly braces:
# ``` C
# // C code
# for(int i=0; i<100; i++)
#    {
#       // curly braces indicate code block
#       total += i;
#    }
# ```
# In Python, code blocks are denoted by *indentation*:
# ``` python
# for i in range(100):
#     # indentation indicates code block
#     total += i
# ```
# ### In Python, indented code blocks are always preceded by a colon (``:``) on the previous line.

# %% [markdown]
# The use of indentation helps to enforce the uniform, readable style that many find appealing in Python code.
# But it might be confusing to the uninitiated; for example, the following two snippets will produce different results:
# ```python
# >>> for x in range(5):         >>> for x in range(5):
# ...     y = x * 2              ...     y = x * 2
# ...     print(y)               ... print(y)
# ```

# %%
# Some white space so that the solution doesn't show up here ;)

# %%
for x in range(5):
    y = x*2
    print(y)

# %%
for x in range(5):
    y = x*2
print(y)

# %%
l = []
for x in range(5):
    y = x*2
    l.append(y)
print(l)

# %% [markdown]
# Finally, you should be aware that the amount of whitespace used for indenting code blocks is up to the user, as long as it is consistent throughout the script. By convention, most style guides recommend to indent code blocks by four spaces. Note that many text editors like Emacs and Vim contain Python modes that do four-space indentation automatically.

# %% [markdown]
# ## Control Flow

# %% [markdown]
# ### Conditional statements: if, elif, else

# %% [markdown]
# The Python syntax for conditional execution of code uses the keywords `if`, `elif` (else if), `else`:

# %%
statement1 = False
statement2 = True

if statement1:
    print("statement1 is True")
    
elif statement2:
    print("statement2 is True")
    
else:
    print("statement1 and statement2 are False")

# %% [markdown]
# As we said, program blocks are defined by their indentation level.

# %% [markdown]
# #### Examples:

# %%
statement1 = statement2 = True

if statement1:
    if statement2:
        print("both statement1 and statement2 are True")

# %%
# Bad indentation!
if statement1:
    if statement2:
    print("both statement1 and statement2 are True")  # this line is not properly indented

# %% [markdown]
# ## Loops

# %% [markdown]
# In Python, loops can be programmed in a number of different ways. The most common is the `for` loop, which is used together with iterable objects, such as lists. The basic syntax is:

# %% [markdown]
# ### **`for` loops**:

# %%
for x in [1,2,3]:
    print(x)

# %% [markdown]
# The `for` loop iterates over the elements of the supplied list, and executes the containing block once for each element. Any kind of list can be used in the `for` loop. For example:

# %%
for x in range(4): # by default range start at 0
    print(x)

# %% [markdown]
# Note: `range(4)` does not include 4 !

# %%
for x in range(-3,3):
    print(x)

# %%
for word in ["scientific", "computing", "with", "python"]:
    print(word)

# %% [markdown]
# #### Tip: Sometimes it is useful to have access to the indices of the values when iterating over a list. We can use the `enumerate` function for this:

# %%
for idx, x in enumerate(range(-3,3)):
    print(idx, x)

# %%
for idx, x in enumerate(["scientific", "computing", "with", "python"]):
    print(idx,x)

# %% [markdown]
# ### List comprehensions: Creating lists using `for` loops:

# %% [markdown]
# A convenient and compact way to initialize lists:

# %%
l2 = []
for x in range(5):
    l2.append(x**2)
    
print(l2)

# %%
L1 = [x**2 for x in range(5)]

print(L1)

# %%
L3 = [el+'a' for el in ["scientific", "computing", "with", "python"]]
print(L3)

# %% [markdown]
# ### `while` loops:

# %%
i = 0

while i < 5:
    print(i)
    
    i = i + 1
    
print("done")

# %% [markdown]
# Note that the `print("done")` statement is not part of the `while` loop body because of the difference in indentation.

# %% [markdown]
# ## Functions

# %% [markdown]
# A function in Python is defined using the keyword `def`, followed by a function name, a signature within parentheses `()`, and a colon `:`. The following code, with one additional level of indentation, is the function body.

# %%
def func0():   
    print("test")

# %%
func0()

# %% [markdown]
# Optionally, but highly recommended, we can define a so called "docstring", which is a description of the functions purpose and behaivor. The docstring should follow directly after the function definition, before the code in the function body.

# %%
def func1(s):
    """
     
    """
    
    print(s + " has " + str(len(s)) + " characters")

# %%
help(func1)

# %%
func1('mississippi')

# %%
## Exercise: What should go in the "description" section of the function above?

# %%
help(func1)

# %%
func1("test")

# %% [markdown]
# Functions that returns a value use the `return` keyword:

# %%
def square(x):
    """
    Return the square of x.
    """
    return x ** 2

# %%
x = square(4)

# %% [markdown]
# We can return multiple values from a function using tuples (see above):

# %%
def powers(x):
    """
    Return a few powers of x.
    """
    return x ** 2, x ** 3, x ** 4

# %%
powers(3)

# %% [markdown]
# ### Default argument and keyword arguments

# %% [markdown]
# In a definition of a function, we can give default values to the arguments the function takes:

# %%
def myfunc(x, p=2, debug=False):
    if debug:
        print("evaluating myfunc for x = " + str(x) + " using exponent p = " + str(p))
    return x**p

# %% [markdown]
# If we don't provide a value of the `debug` argument when calling the the function `myfunc` it defaults to the value provided in the function definition:

# %%
myfunc(5)

# %%
myfunc(5, debug=True)

# %% [markdown]
# If we explicitly list the name of the arguments in the function calls, they do not need to come in the same order as in the function definition. This is called *keyword* arguments, and is often very useful in functions that takes a lot of optional arguments.

# %%
myfunc(p=3, debug=True, x=7)

# %% [markdown]
# ### Unnamed functions (lambda function)

# %% [markdown]
# In Python we can also create unnamed functions, using the `lambda` keyword:

# %%
f1 = lambda x: x**2
    
# is equivalent to 

def f2(x):
    return x**2

# %%
f1(2), f2(2)

# %% [markdown]
# This technique is useful for example when we want to pass a simple function as an argument to another function, like this:

# %%
# map is a built-in python function
map(lambda x: x**2, range(-3,4))

# %% [markdown]
# You could also do this with a list comprehension syntax:

# %%
[x**0.5 for x in range(0,4)]

# %%
# in python 3 we can use `list(...)` to convert the iterator to an explicit list
list(map(lambda x: x**2, range(-3,4)))

# %% [markdown]
# ## Classes

# %% [markdown]
# Classes are the key features of object-oriented programming. A class is a structure for representing an object and the operations that can be performed on the object.
#
# In Python a class can contain *attributes* (variables) and *methods* (functions).
#
# A class is defined almost like a function, but using the `class` keyword, and the class definition usually contains a number of class method definitions (a function in a class).
#
# * Each class method should have an argument `self` as its first argument. This object is a self-reference.
#
# * Some class method names have special meaning, for example:
#
#     * `__init__`: The name of the method that is invoked when the object is first created.
#     * `__str__` : A method that is invoked when a simple string representation of the class is needed, as for example when printed.
#     * There are many more, see http://docs.python.org/3/reference/datamodel.html#special-method-names

# %% [markdown]
# ## Further reading

# %% [markdown]
# * http://www.python.org - The official web page of the Python programming language.
# * http://www.python.org/dev/peps/pep-0008 - Style guide for Python programming. Highly recommended.
# * http://www.greenteapress.com/thinkpython/ - A free book on Python programming.
# * [Python Essential Reference](http://www.amazon.com/Python-Essential-Reference-4th-Edition/dp/0672329786) - A good reference book on Python programming.

# %% [markdown]
# # Exercises
#
# 1\. Create a list that contains the square roots of the numbers between 0 and 10, using a "for" loop.
#
# 2\. Now do the same thing but with a one liner.
#
# 3\. Define a function that returns the larger between two numbers.
#
# 4\. Define a function that finds the percent difference between a number and the constant Pi (use math.pi). [Note: the formula for percent difference is |x-x_ref|/x_ref * 100]
#
# 5\. Define a function that takes a list as input and returns the mean, if the list contains all floating point numbers, and an error message otherwise. Compare the output with numpy mean function.
#
# 6\. You are driving a little too fast, and a police officer stops you. Write code to compute the result, encoded as an int value: 0=no ticket, 1=small ticket, 2=big ticket. If speed is 60 mph or less, the result is 0. If speed is between 61 and 80 mph inclusive, the result is 1. If speed is 81 mph or more, the result is 2. Unless it is your birthday -- on that day, your speed can be 5 mph higher in all cases. Define a function "caught_speeding(speed, is_birthday)" that returns the value of your ticket.
#
# 7\. Not an easy one! Save in a data structure of your choice (e.g. a dictionary) the name and birthday of yourself and two other classmates. Find out (through code) who has the next birthday, and print a happy birthday message to them including their name.
#
# Note: You might wanna take a look at
# http://www.pythonforbeginners.com/basics/python-datetime-time-examples
